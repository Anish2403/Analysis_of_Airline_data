# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("Downloads/Datasets (1)e7e7eed/Datasets/Survey data_Inflight Satisfaction Score.csv")

# %%
df.head()
# Out:
#    flight_number origin_station_code destination_station_code record_locator  \
# 0           3802                 MKX                      ORX         CYXXJJ
# 1           4645                 COX                      DEX         DRXXMH
# 2           5236                 COX                      DEX         DEXXS1
# 3           4686                 DEX                      COX         PXXXLH
# 4            671                 DEX                      COX         KZXXH5
#
#   scheduled_departure_date                                      question_text  \
# 0                 9/1/2022  How satisfied were you with the food & beverag...
# 1                 9/1/2022  How satisfied were you with the food & beverag...
# 2                 9/1/2022  How satisfied were you with the food & beverag...
# 3                 9/1/2022  How satisfied were you with the food & beverag...
# 4                 9/1/2022  How satisfied were you with the food & beverag...
#
#   score satisfaction_type driver_sub_group1               driver_sub_group2  \
# 0     2      Dissatisfied   food & beverage  food and beverage satisfaction
# 1     5         Satisfied   food & beverage  food and beverage satisfaction
# 2     5         Satisfied   food & beverage  food and beverage satisfaction
# 3     3      Dissatisfied   food & beverage  food and beverage satisfaction
# 4     5         Satisfied   food & beverage  food and beverage satisfaction
#
#    ...  equipment_type_code ua_uax actual_flown_miles haul_type  \
# 0  ...                  CRZ    UAX                 67     Short
# 1  ...                  E75    UAX                 72     Short
# 2  ...                  E75    UAX                 72     Short
# 3  ...                  CRJ    UAX                 72     Short
# 4  ...                  19F     UA                 72     Short
#
#   departure_gate  arrival_gate international_domestic_indicator  \
# 0            C12           F10                         Domestic
# 1              5           B60                         Domestic
# 2              7           A71                         Domestic
# 3            B82             5                         Domestic
# 4            B24             3                         Domestic
#
#   response_group media_provider        hub_spoke
# 0     non-member            NaN  spoke departure
# 1         member           GOGO  spoke departure
# 2         member           GOGO  spoke departure
# 3         member            NaN    hub departure
# 4         member      PANASONIC    hub departure
#
# [5 rows x 31 columns]

# %%
plt.style.use('seaborn')
sn.countplot(data=df,x='satisfaction_type')
plt.xlabel('satisfaction_type',fontsize=18)
plt.ylabel('Count',fontsize=18)
plt.title('satisfaction_type distribution',fontsize=18)
plt.show()
# Out:
# C:\Users\Anish\AppData\Local\Temp\ipykernel_20408\3072859631.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # Now considering only satisfied customers

# %%
df = df[df['satisfaction_type'] == 'Satisfied']
df = df.reset_index() 
total_satisfied = len(df)

# %%
print(total_satisfied)
# Out:
# 12610

# %%
haul = []
for i in ('Short' , 'Medium' , 'Long'):
    haul.append(len(df[df['haul_type'] == i]))
print(haul)
# Out:
# [1415, 8003, 3192]

# %%
sn.countplot(data=df,x='haul_type')
plt.xlabel('haul_type',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_type',fontsize=18)
for i in range(0,len(haul)):
    x = round((haul[i]/total_satisfied)*100,2)
    plt.text(i,haul[i],str(x)+'%',ha='center')
plt.show()

# %%
sn.countplot(data=df,x='international_domestic_indicator')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over international_domestic_indicator',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='international_domestic_indicator')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='response_group')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='loyalty_program_level')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='generation')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
sn.histplot(data=df,x='generation',kde=True)
plt.xlabel('Credit score', fontsize=18)
plt.ylabel('Frequency',fontsize=18)
plt.title('Credit score frequency graph',fontsize=18)
plt.show()

# %%
gen = df['generation'].unique() 
plt.pie(df['generation'].value_counts(),labels=gen,
        autopct='%.0f%%')

plt.xlabel('Country', fontsize=18)
plt.title('Country',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='entity')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
sn.countplot(data=df,x='arrival_delay_group')
plt.xlabel('international_domestic_indicator',fontsize=18)
plt.ylabel('satisfaction_type',fontsize=18)
plt.title('satisfaction_type Distribution over haul_tyep',fontsize=18)
plt.show()

# %%
df['cabin_name'].fillna("Bussiness", inplace = True)
# Out:
# 0        Bussiness
# 1        Bussiness
# 2        Bussiness
# 3          Economy
# 4        Bussiness
#            ...
# 12605      Economy
# 12606    Bussiness
# 12607      Economy
# 12608      Economy
# 12609      Economy
# Name: cabin_name, Length: 12610, dtype: object

# %%
lab = df['cabin_name'].unique()
print(lab)
plt.pie(df['cabin_name'].value_counts(),labels=lab,
        autopct='%.0f%%')

plt.xlabel('Country', fontsize=18)
plt.title('Country',fontsize=18)
plt.show()
# Out:
# ['Bussiness' 'Economy' 'Economy Plus']
